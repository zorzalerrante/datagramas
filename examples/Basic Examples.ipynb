# %% [markdown]
# # [matta](https://github.com/carnby/matta) - view and scaffold d3.js visualizations in IPython notebooks
#
# ## basic examples
#
# By [@carnby](https://twitter.com/carnby).
#
# This notebook showcases the basic matta visualizations, as well as their usage.
#
# Note that the `init_javascript` call is not needed when running on local server having added the javascript code to your IPython profile.

# %%
import pandas as pd
import networkx as nx
import matta
import json
import requests

from networkx.readwrite import json_graph

# we do this to load the required libraries when viewing on NBViewer
matta.init_javascript(path='https://rawgit.com/carnby/matta/master/matta/libs')
# Out:
# /home/egraells/Dropbox/phd/apps/matta/matta/visualizations/cartography/template.css
# /home/egraells/Dropbox/phd/apps/matta/matta/visualizations/parsets/template.css
# <script>
# $(document).ready(function() {
#     if (document.location.hostname !== 'localhost') {
#
#
#     if (!require.defined('matta')) {
#         require.config({
#             paths: {
#   "sankey": "https://rawgit.com/carnby/matta/master/matta/libs/d3-sankey/sankey",
#   "cartogram": "https://rawgit.com/carnby/matta/master/matta/libs/d3-cartogram/cartogram",
#   "d3": "https://rawgit.com/carnby/matta/master/matta/libs/d3/d3.min",
#   "leaflet": "https://rawgit.com/carnby/matta/master/matta/libs/leaflet/leaflet",
#   "topojson": "https://rawgit.com/carnby/matta/master/matta/libs/topojson/topojson.min",
#   "parsets": "https://rawgit.com/carnby/matta/master/matta/libs/d3-parsets-1.2.4/d3.parsets",
#   "matta": "https://rawgit.com/carnby/matta/master/matta/libs/matta",
#   "force_edge_bundling": "https://rawgit.com/carnby/matta/master/matta/libs/d3-force-bundling/d3.ForceEdgeBundling",
#   "legend": "https://rawgit.com/carnby/matta/master/matta/libs/d3-legend/d3-legend.min",
#   "cloud": "https://rawgit.com/carnby/matta/master/matta/libs/d3-cloud/d3.layout.cloud",
#   "cola": "https://rawgit.com/carnby/matta/master/matta/libs/cola/cola.min"
# },
#             shim: {
#   "sankey": {
#     "exports": "d3.sankey",
#     "deps": [
#       "d3"
#     ]
#   },
#   "cartogram": {
#     "exports": "d3.cartogram",
#     "deps": [
#       "d3"
#     ]
#   },
#   "cola": {
#     "exports": "cola",
#     "deps": [
#       "d3"
#     ]
#   },
#   "parsets": {
#     "exports": "d3.parsets",
#     "deps": [
#       "d3"
#     ]
#   },
#   "legend": {
#     "exports": "d3.legend",
#     "deps": [
#       "d3"
#     ]
#   }
# },
#         });
#
#         require(['matta'], function(matta) {
#             matta.add_css('https://rawgit.com/carnby/matta/master/matta/libs/matta.css');
#         });
#     }
#
#     }
# });
# </script><span class="label label-info">matta</span> Javascript code added.

# %% [markdown]
# ### Wordclouds
#
# Wordclouds are implemented using the [d3.layout.cloud layout by Jason Davies](http://www.jasondavies.com/wordcloud/). They work with bags of words. The python `Counter` class is perfect for this purposes.

# %%
hamlet = requests.get('http://www.gutenberg.org/cache/epub/2265/pg2265.txt').text
hamlet[0:100]
# Out:
# u"\ufeff***The Project Gutenberg's Etext of Shakespeare's First Folio***\r\n*********************The Tragedie"

# %%
import re
from collections import Counter

words = re.split(r'[\W]+', hamlet.lower())
counts = Counter(words)

# %%
df = pd.DataFrame.from_records(counts.iteritems(), columns=['word', 'frequency'])
df.sort_values(['frequency'], ascending=False, inplace=True)
df.head()
# Out:
#      word  frequency
# 995   the       1108
# 1877  and        920
# 2656   to        762
# 2437   of        698
# 4951  you        593

# %%
matta.wordcloud(dataframe=df.head(500), text='word', font_size='frequency', 
                typeface='Helvetica', font_weight='bold',
               font_color={'value': 'frequency', 'palette': 'cubehelix', 'scale': 'threshold'})
# Out:
# <div id="matta-vis-d748f893-9b45-4f07-94fc-31bbfc879db6"></div>
#
# <script type="text/javascript">
# $(function() {
#     var main = function (d3, matta, cloud) {
#
# /**
#  *
#  * matta_wordcloud was scaffolded using matta - https://github.com/carnby/matta
#  * Variables that start with an underscore (_) are passed as arguments in Python.
#  * Variables that start with _data are data parameters of the visualization, and expected to be given as datum.
#  *
#  * For instance, d3.select('#figure').datum({'graph': a_json_graph, 'dataframe': a_json_dataframe}).call(visualization)
#  * will fill the variables _data_graph and _data_dataframe.
#  *
#  */
#
# var matta_matta_wordcloud = function() {
#     "use strict";
#
#     var __fill_data__ = function(__data__) {
#
#             if (__data__.hasOwnProperty('dataframe')) {
#                 func_matta_wordcloud.dataframe(__data__.dataframe);
#             } else {
#                 func_matta_wordcloud.dataframe(null);
#             }
#
#     };
#
#
#
#     var func_matta_wordcloud = function (selection) {
#         console.log('selection', selection);
#
#         var _vis_width = _width - _padding.left - _padding.right;
#         var _vis_height = _height - _padding.top - _padding.bottom;
#
#         selection.each(function(__data__) {
#             __fill_data__(__data__);
#
#             var container = null;
#             var figure_dom_element = this;
#             var container_legends = null;
#
#             if (d3.select(this).select('svg.matta_wordcloud-container').empty()) {
#
#                     var svg = d3.select(this).append('svg')
#                         .attr('width', _width)
#                         .attr('height', _height)
#                         .attr('class', 'matta_wordcloud-container');
#
#
#
#                     container = svg.append('g')
#                         .classed('matta_wordcloud-container', true)
#                         .attr('transform', 'translate(' + _padding.left + ',' + _padding.top + ')');
#
#                     container_legends = svg.append('g')
#                         .classed('matta_wordcloud-legends', true)
#                         .attr('transform', 'translate(' + _padding.left + ',' + _padding.top + ')');
#
#
#             } else {
#                 container = d3.select(this).select('svg.matta_wordcloud-container');
#             }
#
#             console.log('container', container.node());
#
#
# var cloud_draw = function(vis_container, words, bounds) {
#     statusText.style("display", "none");
#     var scale = bounds ? Math.min(
#         _vis_width / Math.abs(bounds[1].x - _vis_width / 2),
#         _vis_width / Math.abs(bounds[0].x - _vis_width / 2),
#         _vis_height / Math.abs(bounds[1].y - _vis_height / 2),
#         _vis_height / Math.abs(bounds[0].y - _vis_height / 2)) / 2 : 1;
#
#     var text = vis_container.selectAll("text")
#         .data(words, function(d) { return matta.get(d, _text); });
#
#     text.transition()
#         .duration(1000)
#         .attr("transform", function(d) { return "translate(" + [d.x, d.y] + ")rotate(" + d.rotate + ")"; })
#         .style("font-size", function(d) { return d.size + "px"; });
#
#     text.enter().append("text")
#         .attr("text-anchor", "middle")
#         .attr("transform", function(d) { return "translate(" + [d.x, d.y] + ")rotate(" + d.rotate + ")"; })
#         .style("font-size", function(d) { return d.size + "px"; })
#         .style("opacity", 1e-6)
#         .transition()
#         .duration(1000)
#         .style("opacity", _font_opacity);
#
#     text.style("font-family", function(d){ return d.font; })
#         .style("font-weight", _font_weight)
#         .style("fill", _font_color)
#         .text(function(d){ return matta.get(d, _text); });
# };
#
#
#
# var statusText = container.append('text').attr('class', "wordcloud-status").attr('y', 10);
#
# var complete = 0;
# var max = _data_dataframe.length;
# var vis = container.append("g").attr("transform", "translate(" + [_vis_width >> 1, _vis_height >> 1] + ")");
#
# _font_size_update_scale_func(_data_dataframe);
# _font_color_update_scale_func(_data_dataframe);
#
# var color_map = d3.map();
#
# _data_dataframe.forEach(function(d) {
#     console.log('d', d, matta.get(d, _text), _font_color(d));
#     color_map.set(matta.get(d, _text), _font_color(d));
# });
#
# console.log('color map', color_map);
#
# var layout = cloud()
#     .size([_vis_width, _vis_height])
#     .font(_typeface)
#     .fontWeight(_font_weight)
#     .fontSize(_font_size)
#     .text(function(d) { return matta.get(d, _text); })
#     .rotate(_rotation)
#     .on("word", function(d) { return statusText.text(++complete + "/" + max); })
#     .on("end", function(words, bounds) {
#         cloud_draw(vis, words, bounds);
#     });
#
# statusText.style("display", null);
# layout.stop().words(_data_dataframe).start();
#
#         });
#     };
#
#
#         var _data_dataframe = null;
#         func_matta_wordcloud.dataframe = function(__) {
#             if (arguments.length) {
#                 _data_dataframe = __;
#                 console.log('DATA dataframe', _data_dataframe);
#                 return func_matta_wordcloud;
#             }
#             return _data_dataframe;
#         };
#
#
#     var active_legends = [];
#
#
#
#     var _font_size = null;
#     var _font_size_scale = null;
#     var _font_size_scale_locked = false;
#     var _font_size_update_scale_func = d3.functor(null);
#     var _font_size_show_legend = false;
#     var _font_size_legend = null;
#     var _font_size_legend_container = null;
#
#     func_matta_wordcloud.font_size_scale_locked = function(__) {
#         /**
#          * If font_size's scale is locked, then matta_wordcloud will not automatically update it
#          * before rendering. Useful to set the scale parameters from outside, or to maintain
#          * coherent scaling between succesive renderings.
#          */
#         if (arguments.length) {
#             _font_size_scale_locked = __;
#             console.log('set font_size_scale_locked', _font_size_scale_locked);
#             return func_matta_wordcloud;
#         }
#         return _font_size_scale_locked;
#     };
#
#     func_matta_wordcloud.font_size_scale = function() {
#         /**
#          * Returns the scale for font_size.
#          */
#         return _font_size_scale;
#     };
#
#     // {'max': '64', 'scale': '"sqrt"', u'legend': 'false', 'value': '"frequency"', 'min': '8'}
#     // TODO: create get/setters for these variables
#     var _font_size_scale_type = "sqrt";
#     var _font_size_min = 8;
#     var _font_size_max = 64;
#     var _font_size_value = "frequency";
#
#     if (typeof(_font_size_value) !== 'string') {
#         console.log('font_size using a functor', _font_size_value);
#         _font_size = d3.functor(_font_size_value !== null ? _font_size_value : _font_size_max);
#     } else {
#         _font_size_scale = matta.scale(_font_size_scale_type);
#         _font_size_scale.range([_font_size_min, _font_size_max]);
#
#         _font_size = function(d) {
#             //console.log('_font_size', d, _font_size_value, _font_size_scale(matta.get(d, _font_size_value)));
#             return _font_size_scale(matta.get(d, _font_size_value));
#         };
#
#         _font_size_update_scale_func = function(data) {
#             if (_font_size_scale_locked) {
#                 return;
#             }
#
#             _font_size_scale.range([_font_size_min, _font_size_max]);
#             _font_size_scale.domain(d3.extent(data, function(d) {
#                 return matta.get(d, _font_size_value);
#                 })
#             );
#         };
#
#         if (_font_size_show_legend) {
#             _font_size_legend = d3.legend.size()
#                     .scale(_font_size_scale)
#                     // TODO: these should be parameterizable
#                     .shape('circle')
#                     .shapePadding(15)
#                     .labelOffset(20)
#                     //.labelFormat(d3.format('.3f'))
#                     .title(_font_size_value);
#
#             _font_size_legend['variable'] = 'font_size';
#             console.log('font_size legend', _fo

# %% [markdown]
# ### Treemaps
#
# Treemaps use the [Treemap Layout from d3.js](https://github.com/mbostock/d3/wiki/Treemap-Layout). They work with trees, which we construct through [`networkx.DiGraph`](http://networkx.github.io/documentation/networkx-1.9.1/reference/classes.digraph.html).

# %%
flare_data = requests.get('https://gist.githubusercontent.com/mbostock/4063582/raw/a05a94858375bd0ae023f6950a2b13fac5127637/flare.json').json()
# Out:
# /home/egraells/.virtualenvs/ipython/local/lib/python2.7/site-packages/requests/packages/urllib3/util/ssl_.py:100: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning

# %%
flare_data['name']
# Out:
# u'flare'

# %%
tree = nx.DiGraph()

def add_node(node):
    node_id = tree.number_of_nodes() + 1
    n = tree.add_node(node_id, name=node['name'])
    
    if 'size' in node:
        tree.node[node_id]['size'] = node['size']
    
    if 'children' in node:
        for child in node['children']:
            child_id = add_node(child)
            tree.add_edge(node_id, child_id)
    
    return node_id

root = add_node(flare_data)
# treemap requires this attribute
tree.graph['root'] = root

# %%
nx.is_arborescence(tree)
# Out:
# True

# %%
import seaborn as sns

# %%
matta.treemap(tree=tree, node_value='size', node_label='name',
              node_color={'value': 'parent.name', 'scale': 'ordinal', 'palette': sns.husl_palette(15, l=.4, s=.9)})
# Out:
# <div id="matta-vis-13671ab3-01c9-4bd7-afbc-77e9d56fd81a"></div>
#
# <script type="text/javascript">
# $(function() {
#     var main = function (d3, matta) {
#
# /**
#  *
#  * matta_treemap was scaffolded using matta - https://github.com/carnby/matta
#  * Variables that start with an underscore (_) are passed as arguments in Python.
#  * Variables that start with _data are data parameters of the visualization, and expected to be given as datum.
#  *
#  * For instance, d3.select('#figure').datum({'graph': a_json_graph, 'dataframe': a_json_dataframe}).call(visualization)
#  * will fill the variables _data_graph and _data_dataframe.
#  *
#  */
#
# var matta_matta_treemap = function() {
#     "use strict";
#
#     var __fill_data__ = function(__data__) {
#
#             if (__data__.hasOwnProperty('tree')) {
#                 func_matta_treemap.tree(__data__.tree);
#             } else {
#                 func_matta_treemap.tree(null);
#             }
#
#     };
#
#
#
#     var func_matta_treemap = function (selection) {
#         console.log('selection', selection);
#
#         var _vis_width = _width - _padding.left - _padding.right;
#         var _vis_height = _height - _padding.top - _padding.bottom;
#
#         selection.each(function(__data__) {
#             __fill_data__(__data__);
#
#             var container = null;
#             var figure_dom_element = this;
#             var container_legends = null;
#
#             if (d3.select(this).select('div.matta_treemap-container').empty()) {
#
#                     // NOTE: a vis. of this kind should manage the legends container (which should be an svg) by itself.
#                     var div = d3.select(this).append('div')
#                         .style({
#
#                             'width': _width + 'px',
#                             'height': _height + 'px',
#
#                             'position': 'relative',
#                             'display': 'block'
#                         })
#                         .classed('matta_treemap-container', true);
#
#
#
#                     container = div;
#
#
#             } else {
#                 container = d3.select(this).select('div.matta_treemap-container');
#             }
#
#             console.log('container', container.node());
#
#
#
#
#
#
#     var calc_fontsize = d3.functor(_font_size);
#
#
# var treemap = d3.layout.treemap()
#     .size([_width, _height])
#     .value(function(d) { return matta.get(d, _node_value); })
#     .children(function(d) { return matta.get(d, _node_children); })
#     .padding(_node_padding)
#     .ratio(_target_ratio)
#     .mode(_mode)
#     .sticky(_sticky);
#
# //_node_color_update_scale_func()
#
# var root = treemap.nodes(_data_tree);
# console.log('root', root);
# _node_color_update_scale_func(root);
#
# console.log('nodes', root);
# var cell = container
#     .selectAll("div.node")
#     .data(root, function(d) {
#         return matta.get(d, _node_id);
#     });
#
# var node_background = function(d) {
#     if (_color_level >= 0 && _color_level !== d.depth) {
#         return 'none';
#     }
#
#     if (matta.get(d, _node_children) !== null) {
#         return 'none';
#     }
#
#     console.log('colorable', matta.get(d, _node_label), matta.get(d, _node_value), _node_color(d), d);
#     return _node_color(d);
# };
#
# var node_text = function(d) {
#     if (_label_leaves_only && matta.get(d, _node_children) != null) {
#         return null;
#     }
#     return _node_label != null ? matta.get(d, _node_label) : null;
# };
#
# var node_color = function(d) {
#     var color = node_background(d);
#     if (node_text(d) !== null && color !== 'none') {
#         return matta.text_color(color);
#     }
#
#     return null;
# };
#
# cell.enter()
#     .append("div")
#     .classed('node', true)
#     .style({
#         'font-size': function(d) { return calc_fontsize(d) + 'px'; },
#         'position': 'absolute',
#         'background-color': node_background,
#         'border': _border_color + ' ' + _node_border + 'px solid',
#         'overflow': 'hidden',
#         'color': node_color
#     })
#     .text(node_text);
#
# cell.style({
#     'left': function(d) { return d.x + 'px'; },
#     'top': function(d) { return d.y + 'px'; },
#     'width': function(d) { return Math.max(0, d.dx - (2 * _node_padding)) + 'px'; },
#     'height': function(d) { return Math.max(0, d.dy - (2 * _node_padding)) + 'px'; }
# });
#
# cell.sort(function(a, b) { return d3.ascending(a.depth, b.depth); });
#
#
#
#
#
#
#
#
#         });
#     };
#
#
#         var _data_tree = null;
#         func_matta_treemap.tree = function(__) {
#             if (arguments.length) {
#                 _data_tree = __;
#                 console.log('DATA tree', _data_tree);
#                 return func_matta_treemap;
#             }
#             return _data_tree;
#         };
#
#
#     var active_legends = [];
#
#
#
#
#     var _node_color = null;
#     var _node_color_scale = null;
#     var _node_color_scale_locked = false;
#     var _node_color_update_scale_func = d3.functor(null);
#
#     func_matta_treemap.node_color_scale_locked = function(__) {
#         /**
#          * If node_color's color scale is locked, then matta_treemap will not automatically update it
#          * before rendering. Useful to set the scale parameters from outside, or to maintain
#          * coherent scaling between succesive renderings.
#          */
#         if (arguments.length) {
#             _node_color_scale_locked = __;
#             console.log('set node_color_scale_locked', _node_color_scale_locked);
#             return func_matta_treemap;
#         }
#         return _node_color_scale_locked;
#     };
#
#     func_matta_treemap.node_color_scale = function() {
#         /**
#          * Returns the color scale for node_color.
#          */
#         return _node_color_scale;
#     };
#
#     var _node_color_value = "parent.name";
#
#     // to the outside, this function sets/gets the variable we use
#     func_matta_treemap.node_color = function(__) {
#         if (arguments.length) {
#             //TODO: consider the case when the value is fixed, not a variable
#             _node_color_value = __;
#             return func_matta_treemap;
#         }
#         return _node_color_value;
#     };
#
#     // {'palette': '["#b41c46", "#94481a", "#7a571a", "#685e1a", "#54641a", "#2d6a1a", "#1b6a48", "#1c685b", "#1d6769", "#1e6577", "#206290", "#4b40e8", "#9225ba", "#a22296", "#ab1f77"]', 'scale': '"ordinal"', u'domain': 'null', 'value': '"parent.name"', 'n_colors': '15', 'legend': 'false'}
#     // TODO: create get/setters for these variables
#
#     var _node_color_palette = ["#b41c46", "#94481a", "#7a571a", "#685e1a", "#54641a", "#2d6a1a", "#1b6a48", "#1c685b", "#1d6769", "#1e6577", "#206290", "#4b40e8", "#9225ba", "#a22296", "#ab1f77"];
#     var _node_color_domain = null;
#     var _node_color_scale_type = "ordinal";
#     var _node_color_show_legend = false;
#     var _node_color_legend = null;
#     var _node_color_legend_container = null;
#
#     if (_node_color_palette !== null) {
#         if (_node_color_scale_type === 'threshold' || _node_color_scale_type === 'quantize') {
#             _node_color_scale = d3.scale.quantize().range(_node_color_palette);
#
#         } else if (_node_color_scale_type === 'ordinal') {
#             _node_color_scale = d3.scale.ordinal().range(_node_color_palette);
#         } else {
#             throw 'node_color: Undefined color scale "ordinal".';
#         }
#
#         if (_node_color_domain !== null) {
#             // if manually specified, we lock the scale
#             _node_color_scale.domain(_node_color_domain);
#             _node_color_scale_locked = true;
#         }
#
#         _node_color_update_scale_func = function(data) {
#             // updates the domain before draw
#             if (_node_color_scale_locked) {
#                 return;
#             }
#
#             _node_color_scale.domain(
#                 _node_color_scale_type === 'threshold' || _node_color_scale_type === 'quantize' ?
#                     d3.extent(data, function(d) { return matta.get(d, _node_color_value); }) :

# %% [markdown]
# ### Sankey
#
# Sankey or flow diagrams use the [Sankey plugin by Mike Bostock](http://bost.ocks.org/mike/sankey/). They work with digraphs, just like treemaps. Note that graphs with loops are not supported.

# %%
sankey_data = requests.get('http://bost.ocks.org/mike/sankey/energy.json')

# %%
sankey_graph = json_graph.node_link_graph(json.loads(sankey_data.text), directed=True)

# %%
sankey_graph.nodes_iter(data=True).next(), sankey_graph.edges_iter(data=True).next()
# Out:
# ((0, {u'name': u"Agricultural 'waste'"}), (0, 1, {u'value': 124.729}))

# %%
matta.flow(graph=sankey_graph, node_label='name', link_weight='value', node_color='indigo', 
       node_width=12, node_padding=13,
       link_color={'value': 'value', 'palette': 'Greys', 'scale': 'threshold'}, link_opacity=0.8)
# Out:
# <div id="matta-vis-c5ae3491-c351-40ea-9dd8-c7a461fda4a1"></div>
#
# <script type="text/javascript">
# $(function() {
#     var main = function (d3, matta, sankey) {
#
# /**
#  *
#  * matta_flow was scaffolded using matta - https://github.com/carnby/matta
#  * Variables that start with an underscore (_) are passed as arguments in Python.
#  * Variables that start with _data are data parameters of the visualization, and expected to be given as datum.
#  *
#  * For instance, d3.select('#figure').datum({'graph': a_json_graph, 'dataframe': a_json_dataframe}).call(visualization)
#  * will fill the variables _data_graph and _data_dataframe.
#  *
#  */
#
# var matta_matta_flow = function() {
#     "use strict";
#
#     var __fill_data__ = function(__data__) {
#
#             if (__data__.hasOwnProperty('graph')) {
#                 func_matta_flow.graph(__data__.graph);
#             } else {
#                 func_matta_flow.graph(null);
#             }
#
#     };
#
#
#
#     var func_matta_flow = function (selection) {
#         console.log('selection', selection);
#
#         var _vis_width = _width - _padding.left - _padding.right;
#         var _vis_height = _height - _padding.top - _padding.bottom;
#
#         selection.each(function(__data__) {
#             __fill_data__(__data__);
#
#             var container = null;
#             var figure_dom_element = this;
#             var container_legends = null;
#
#             if (d3.select(this).select('svg.matta_flow-container').empty()) {
#
#                     var svg = d3.select(this).append('svg')
#                         .attr('width', _width)
#                         .attr('height', _height)
#                         .attr('class', 'matta_flow-container');
#
#
#
#                     container = svg.append('g')
#                         .classed('matta_flow-container', true)
#                         .attr('transform', 'translate(' + _padding.left + ',' + _padding.top + ')');
#
#                     container_legends = svg.append('g')
#                         .classed('matta_flow-legends', true)
#                         .attr('transform', 'translate(' + _padding.left + ',' + _padding.top + ')');
#
#
#             } else {
#                 container = d3.select(this).select('svg.matta_flow-container');
#             }
#
#             console.log('container', container.node());
#
#
#
#
#
# // we do this because the d3-sankey layout has hardcoded the value variable.
# matta.prepare_graph(_data_graph);
#
# _data_graph.links.forEach(function(d) {
#     d.value = matta.get(d, _link_weight);
# });
#
# _node_color_update_scale_func(_data_graph.nodes);
# _link_color_update_scale_func(_data_graph.links);
#
#
#     var sankey_width = _width - _padding.left - _padding.right;
#     var sankey_height = _height - _padding.top - _padding.bottom;
#     var sankey_transform = "translate(0,0)";
#
#
# var sankey_svg;
# var links_g;
# var nodes_g;
#
# if (!container.select('g.d3-sankey-root').empty()) {
#     sankey_svg = container.select('g.d3-sankey-root');
# } else {
#     sankey_svg = container.append('g').attr('transform', sankey_transform).classed('d3-sankey-root', true);
# }
#
# if (!sankey_svg.select('g.d3-sankey-links').empty()) {
#     links_g = sankey_svg.select('g.d3-sankey-links');
# } else {
#     links_g = sankey_svg.append('g').classed('d3-sankey-links', true);
# }
#
# if (!sankey_svg.select('g.d3-sankey-nodes').empty()) {
#     nodes_g = sankey_svg.select('g.d3-sankey-nodes');
# } else {
#     nodes_g = sankey_svg.append('g').classed('d3-sankey-nodes', true);
# }
#
# var scale_container;
#
# if (!container.select('g.color-legend').empty()) {
#     scale_container = container.select('g.color-legend');
# } else {
#     scale_container = container.append('g').classed('color-legend legend', true);
# }
#
# var layout = sankey()
#     .nodeWidth(_node_width)
#     .nodePadding(_node_padding)
#     .size([sankey_width, sankey_height]);
#
# var sankey_path = layout.link();
#
# layout
#     .nodes(_data_graph.nodes)
#     .links(_data_graph.links)
#     .layout(_layout_iterations);
#
# var link = links_g.selectAll("path.link")
#     .data(_data_graph.links);
#
# link.enter().append("path")
#     .attr("class", "link");
#
# link.exit()
#     .remove();
#
# link.style({
#         'stroke-width': function(d){ return Math.max(1, d.dy); },
#         'opacity': _link_opacity,
#         'stroke': _link_color,
#         'fill': 'none'
#     })
#     .sort(function(a, b){ return b.dy - a.dy; });
#
# link.attr("d", sankey_path);
# link.style('stroke', _link_color);
#
# var node = nodes_g.selectAll("g.node")
#     .data(_data_graph.nodes);
#
# node.enter().append("g")
#     .attr("class", "node");
#
# node.exit().remove();
#
# node.attr("transform", function(d){  return "translate(" + d.x + "," + d.y + ")"; });
#
# node.append("rect")
#     .attr("height", function(d){ return d.dy; })
#     .attr("width", layout.nodeWidth())
#     .style({
#         "stroke": function(d){ return d3.rgb(d.color).darker(2); },
#         'fill': _node_color,
#         'fill-opacity': _node_opacity
#     });
#
# node.append("text")
#     .attr("x", -6)
#     .attr("y", function(d){ return d.dy / 2; })
#     .attr("dy", ".35em")
#     .attr("text-anchor", "end")
#     .attr("transform", null)
#     .attr('font-size', _font_size)
#     .text(function(d) { return matta.get(d, _node_label); })
#     .filter(function(d){ return d.x > sankey_width / 2; })
#     .attr("x", 6 + layout.nodeWidth())
#     .attr("text-anchor", "start");
#
#
#         });
#     };
#
#
#         var _data_graph = null;
#         func_matta_flow.graph = function(__) {
#             if (arguments.length) {
#                 _data_graph = __;
#                 console.log('DATA graph', _data_graph);
#                 return func_matta_flow;
#             }
#             return _data_graph;
#         };
#
#
#     var active_legends = [];
#
#
#
#
#     var _link_color = null;
#     var _link_color_scale = null;
#     var _link_color_scale_locked = false;
#     var _link_color_update_scale_func = d3.functor(null);
#
#     func_matta_flow.link_color_scale_locked = function(__) {
#         /**
#          * If link_color's color scale is locked, then matta_flow will not automatically update it
#          * before rendering. Useful to set the scale parameters from outside, or to maintain
#          * coherent scaling between succesive renderings.
#          */
#         if (arguments.length) {
#             _link_color_scale_locked = __;
#             console.log('set link_color_scale_locked', _link_color_scale_locked);
#             return func_matta_flow;
#         }
#         return _link_color_scale_locked;
#     };
#
#     func_matta_flow.link_color_scale = function() {
#         /**
#          * Returns the color scale for link_color.
#          */
#         return _link_color_scale;
#     };
#
#     var _link_color_value = "value";
#
#     // to the outside, this function sets/gets the variable we use
#     func_matta_flow.link_color = function(__) {
#         if (arguments.length) {
#             //TODO: consider the case when the value is fixed, not a variable
#             _link_color_value = __;
#             return func_matta_flow;
#         }
#         return _link_color_value;
#     };
#
#     // {'palette': '["#ededed", "#d1d1d1", "#adadad", "#828282", "#5c5c5c", "#2b2b2b"]', 'scale': '"threshold"', u'domain': 'null', 'value': '"value"', 'n_colors': '6', 'legend': 'false'}
#     // TODO: create get/setters for these variables
#
#     var _link_color_palette = ["#ededed", "#d1d1d1", "#adadad", "#828282", "#5c5c5c", "#2b2b2b"];
#     var _link_color_domain = null;
#     var _link_color_scale_type = "threshold";
#     var _link_color_show_legend = false;
#     var _link_color_legend = null;
#     var _link_color_legend_container = null;
#
#     if (_link_color_palette !== null) {
#         if (_link_color_scale_type === 'threshold' || _link_color_scale_type === 'quantize') {
#             _link_color_scale = d3.scale.quantize().range(_link_color_palette);
#
#         } else if (_link_color_scale_type === 'ordinal') {
#             _link_color_scale = d3.scale.ordinal().range(_link_color_palette);
#         } else {
#             throw 'link_co

# %% [markdown]
# ### Parallel Coordinates
#
# Parallel Coordinates are based on the [code by Jason Davies](http://bl.ocks.org/jasondavies/1341281). They work with [`pandas.DataFrame`](http://pandas.pydata.org/pandas-docs/stable/dsintro.html#dataframe).

# %%
df = pd.read_csv('http://bl.ocks.org/jasondavies/raw/1341281/cars.csv', index_col='name')
df.head()
# Out:
#                          economy (mpg)  cylinders  displacement (cc)  \
# name
# AMC Ambassador Brougham           13.0          8                360
# AMC Ambassador DPL                15.0          8                390
# AMC Ambassador SST                17.0          8                304
# AMC Concord DL 6                  20.2          6                232
# AMC Concord DL                    18.1          6                258
#
#                          power (hp)  weight (lb)  0-60 mph (s)  year
# name
# AMC Ambassador Brougham         175         3821          11.0    73
# AMC Ambassador DPL              190         3850           8.5    70
# AMC Ambassador SST              150         3672          11.5    72
# AMC Concord DL 6                 90         3265          18.2    79
# AMC Concord DL                  120         3410          15.1    78

# %%
matta.parcoords(dataframe=df)
# Out:
# <div id="matta-vis-b8718d3b-d6d3-459a-af15-6c1dff80a642"></div>
#
# <script type="text/javascript">
# $(function() {
#     var main = function (d3, matta) {
#
# /**
#  *
#  * matta_parcoords was scaffolded using matta - https://github.com/carnby/matta
#  * Variables that start with an underscore (_) are passed as arguments in Python.
#  * Variables that start with _data are data parameters of the visualization, and expected to be given as datum.
#  *
#  * For instance, d3.select('#figure').datum({'graph': a_json_graph, 'dataframe': a_json_dataframe}).call(visualization)
#  * will fill the variables _data_graph and _data_dataframe.
#  *
#  */
#
# var matta_matta_parcoords = function() {
#     "use strict";
#
#     var __fill_data__ = function(__data__) {
#
#             if (__data__.hasOwnProperty('dataframe')) {
#                 func_matta_parcoords.dataframe(__data__.dataframe);
#             } else {
#                 func_matta_parcoords.dataframe(null);
#             }
#
#     };
#
#
#         var dispatch = d3.dispatch('click');
#
#
#     var func_matta_parcoords = function (selection) {
#         console.log('selection', selection);
#
#         var _vis_width = _width - _padding.left - _padding.right;
#         var _vis_height = _height - _padding.top - _padding.bottom;
#
#         selection.each(function(__data__) {
#             __fill_data__(__data__);
#
#             var container = null;
#             var figure_dom_element = this;
#             var container_legends = null;
#
#             if (d3.select(this).select('svg.matta_parcoords-container').empty()) {
#
#                     var svg = d3.select(this).append('svg')
#                         .attr('width', _width)
#                         .attr('height', _height)
#                         .attr('class', 'matta_parcoords-container');
#
#
#
#                     container = svg.append('g')
#                         .classed('matta_parcoords-container', true)
#                         .attr('transform', 'translate(' + _padding.left + ',' + _padding.top + ')');
#
#                     container_legends = svg.append('g')
#                         .classed('matta_parcoords-legends', true)
#                         .attr('transform', 'translate(' + _padding.left + ',' + _padding.top + ')');
#
#
#             } else {
#                 container = d3.select(this).select('svg.matta_parcoords-container');
#             }
#
#             console.log('container', container.node());
#
#
#
#
#
# function position(d) {
#     var v = dragging[d];
#     return v == null ? x(d) : v;
# };
#
# // Returns the path for a given data point.
# var path = function(d, i) {
#     var points = _columns.map(function(p) {
#         return [position(p), y[p](d[p])];
#     });
#     return line(points);
# };
#
# // Handles a brush event, toggling the display of foreground lines.
# function brush() {
#     var actives = _columns.filter(function(p) {
#         return !y[p].brush.empty();
#     });
#
#     var extents = actives.map(function(p) {
#         return y[p].brush.extent();
#     });
#
#     console.log('actives', actives, extents);
#
#     foreground.style("display", function(d) {
#     return actives.every(function(p, i) {
#             console.log(d, p, i);
#             return extents[i][0] <= d[p] && d[p] <= extents[i][1];
#         }) ? null : "none";
#     });
# };
#
#
# var w = _width - _padding.left - _padding.right;
# var h = _height - _padding.top - _padding.bottom;
#
# var x = d3.scale.ordinal().rangePoints([0, w], 1),
#     y = {},
#     dragging = {};
#
# var line = d3.svg.line(),
#     axis = d3.svg.axis().orient("left"),
#     foreground,
#     _idx = {};
#
#
# var color = d3.functor('steelblue');
#
# var pc_g = container.append("g");
#
# _columns.forEach(function(d, i) {
#     _idx[d] = i;
# });
#
# _columns.forEach(function(d, i) {
#     y[d] = d3.scale.linear().domain(d3.extent(_data_dataframe, function(p) {
#         return p[d];
#     })).range([h, 0]);
#
#     console.log('y', d, y[d].domain());
# });
#
# console.log('y', y);
#
#
# // Extract the list of dimensions and create a scale for each.
# x.domain(_columns);
#
# console.log('x', x.domain(), x.range());
#
#
# // Add blue foreground lines for focus.
# foreground = pc_g.append("svg:g")
#     .attr("class", "foreground")
# .selectAll("path")
#     .data(_data_dataframe)
# .enter().append("svg:path")
#     .attr("d", path)
# .attr('opacity', _line_opacity)
# .attr('stroke', color)
# .attr('stroke-width', _line_stroke_width)
# .attr('fill', 'none')
# .on('click', function(d) {
#     _dispatcher.click.apply(this, arguments);
#     console.log(this, arguments);
# });
#
# // Add a group element for each dimension.
# var g = pc_g.selectAll(".dimension")
#     .data(_columns)
# .enter().append("svg:g")
#     .attr("class", "dimension")
#     .attr("transform", function(d) { return "translate(" + x(d) + ")"; })
#     .call(d3.behavior.drag()
#         .on("dragstart", function(d) {
#             dragging[d] = this.__origin__ = x(d);
#             //background.attr("visibility", "hidden");
#         })
#         .on("drag", function(d) {
#             dragging[d] = Math.min(w, Math.max(0, this.__origin__ += d3.event.dx));
#             foreground.attr("d", path);
#             _columns.sort(function(a, b) { return position(a) - position(b); });
#             x.domain(_columns);
#             g.attr("transform", function(d) { return "translate(" + position(d) + ")"; })
#         })
#         .on("dragend", function(d) {
#             delete this.__origin__;
#             delete dragging[d];
#             d3.select(this).attr("transform", "translate(" + x(d) + ")");
#             foreground.attr("d", path);
#
#         })
#     );
#
# // Add an axis and title.
# g.append("svg:g")
#     .attr("class", "axis")
#     .each(function(d, i) {
#         var self = d3.select(this);
#         self.call(axis.scale(y[d]));
#         self.selectAll('line').style({'display': 'block', 'stroke': '#000', 'fill': 'none', 'shape-rendering': 'crispEdges'});
#         self.selectAll('path').style({'display': 'block', 'stroke': '#000', 'fill': 'none', 'shape-rendering': 'crispEdges'});
#     })
# .append("svg:text")
#     .attr("text-anchor", "middle")
#     .attr("y", -9)
#     .text(String);
#
# // Add and store a brush for each axis.
# g.append("svg:g")
#     .attr("class", "brush")
#     .each(function(d, i) {
#         var self = d3.select(this);
#
#         self.call(y[d].brush = d3.svg.brush().y(y[d])
#                 .on("brush", brush)
#             );
#         self.select('.extent').style({
#           'fill-opacity': 0.3,
#           'stroke': '#fff',
#           'shape-rendering': 'crispEdges'
#         });
#     })
# .selectAll("rect")
#     .attr("x", -8)
#     .attr("width", 16);
#
#
#
#
#
#
#
#
#         });
#     };
#
#
#         var _data_dataframe = null;
#         func_matta_parcoords.dataframe = function(__) {
#             if (arguments.length) {
#                 _data_dataframe = __;
#                 console.log('DATA dataframe', _data_dataframe);
#                 return func_matta_parcoords;
#             }
#             return _data_dataframe;
#         };
#
#
#     var active_legends = [];
#
#
#
#
#     // TODO: make a more flexible system.
#     // TODO: Allow "outer", "middle" and "center"
#     var allowed_locations = [['upper', 'right'], ['lower', 'right'], ['lower', 'left'], ['upper', 'left']];
#
#     var draw_legends = function(container_legends, width, height) {
#         /**
#          * This function draws the current legends into the specified container.
#          */
#
#         var legend = container_legends.selectAll('g.matta-legend')
#             .data(active_legends, function(d) { return d['variable']; });
#
#         legend.enter()
#             .append('g')
#             .attr('class', function(d) { return 'matta-legend'; });
#
#         legend.exit()
#             .remove();
#
#         legend.each(function(d, i) {
#             console.log('each legend', d, this);
#             var self = d3.select(this);
#             self.call(d);
#             var bbox = self.node().getBBox();
#             console.log('bbox', bbox);
#
#             // hack to avoid problems with too many legends.
#             var location = allowed_location

# %% [markdown]
# ### Parallel Sets

# %%
df = pd.read_csv('https://www.jasondavies.com/parallel-sets/titanic.csv')
df.head()
# Out:
#           Class    Age     Sex  Survived
# 0  Second Class  Child  Female  Survived
# 1  Second Class  Child  Female  Survived
# 2  Second Class  Child  Female  Survived
# 3  Second Class  Child  Female  Survived
# 4  Second Class  Child  Female  Survived

# %%
matta.parsets(dataframe=df, columns=['Survived', 'Sex', 'Age', 'Class'])
# Out:
# <style>
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .dimension { cursor: ns-resize; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .category { cursor: ew-resize; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .dimension tspan.name { font-size: 1.5em; fill: #333; font-weight: bold; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .dimension tspan.sort { fill: #000; cursor: pointer; opacity: 0; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .dimension tspan.sort:hover { fill: #333; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .dimension:hover tspan.name { fill: #000; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .dimension:hover tspan.sort { opacity: 1; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .dimension line { stroke: #000; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .dimension rect { stroke: none; fill-opacity: 0; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .dimension > rect, .category-background { fill: #fff; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .dimension > rect { display: none; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .category:hover rect { fill-opacity: .3; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .dimension:hover > rect { fill-opacity: .3; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .ribbon path { stroke-opacity: 0; fill-opacity: .5; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .ribbon path.active { fill-opacity: .9; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .ribbon-mouse path { fill-opacity: 0; }
#
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .category-0 { fill: #1f77b4; stroke: #1f77b4; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .category-1 { fill: #ff7f0e; stroke: #ff7f0e; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .category-2 { fill: #2ca02c; stroke: #2ca02c; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .category-3 { fill: #d62728; stroke: #d62728; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .category-4 { fill: #9467bd; stroke: #9467bd; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .category-5 { fill: #8c564b; stroke: #8c564b; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .category-6 { fill: #e377c2; stroke: #e377c2; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .category-7 { fill: #7f7f7f; stroke: #7f7f7f; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .category-8 { fill: #bcbd22; stroke: #bcbd22; }
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .category-9 { fill: #17becf; stroke: #17becf; }
#
# #matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57 .tooltip {
#   background-color: rgba(242, 242, 242, .6);
#   position: absolute;
#   padding: 5px;
# }
# </style>
#
#
# <div id="matta-vis-a8ce48d3-b113-41d1-89b4-2c40a6fc9b57"></div>
#
# <script type="text/javascript">
# $(function() {
#     var main = function (d3, parsets) {
#
# /**
#  *
#  * matta_parsets was scaffolded using matta - https://github.com/carnby/matta
#  * Variables that start with an underscore (_) are passed as arguments in Python.
#  * Variables that start with _data are data parameters of the visualization, and expected to be given as datum.
#  *
#  * For instance, d3.select('#figure').datum({'graph': a_json_graph, 'dataframe': a_json_dataframe}).call(visualization)
#  * will fill the variables _data_graph and _data_dataframe.
#  *
#  */
#
# var matta_matta_parsets = function() {
#     "use strict";
#
#     var __fill_data__ = function(__data__) {
#
#             if (__data__.hasOwnProperty('dataframe')) {
#                 func_matta_parsets.dataframe(__data__.dataframe);
#             } else {
#                 func_matta_parsets.dataframe(null);
#             }
#
#     };
#
#
#
#     var func_matta_parsets = function (selection) {
#         console.log('selection', selection);
#
#         var _vis_width = _width - _padding.left - _padding.right;
#         var _vis_height = _height - _padding.top - _padding.bottom;
#
#         selection.each(function(__data__) {
#             __fill_data__(__data__);
#
#             var container = null;
#             var figure_dom_element = this;
#             var container_legends = null;
#
#             if (d3.select(this).select('svg.matta_parsets-container').empty()) {
#
#                     var svg = d3.select(this).append('svg')
#                         .attr('width', _width)
#                         .attr('height', _height)
#                         .attr('class', 'matta_parsets-container');
#
#
#
#                     container = svg.append('g')
#                         .classed('matta_parsets-container', true)
#                         .attr('transform', 'translate(' + _padding.left + ',' + _padding.top + ')');
#
#                     container_legends = svg.append('g')
#                         .classed('matta_parsets-legends', true)
#                         .attr('transform', 'translate(' + _padding.left + ',' + _padding.top + ')');
#
#
#             } else {
#                 container = d3.select(this).select('svg.matta_parsets-container');
#             }
#
#             console.log('container', container.node());
#
#
#
#
#
#
# if (_columns == null) {
#       _columns = d3.keys(_data_dataframe[0]);
# }
#
# var chart = parsets()
#       .dimensions(_columns)
#       .height(_vis_height)
#       .width(_vis_width);
#
# container.datum(_data_dataframe).call(chart);
#
#         });
#     };
#
#
#         var _data_dataframe = null;
#         func_matta_parsets.dataframe = function(__) {
#             if (arguments.length) {
#                 _data_dataframe = __;
#                 console.log('DATA dataframe', _data_dataframe);
#                 return func_matta_parsets;
#             }
#             return _data_dataframe;
#         };
#
#
#     var active_legends = [];
#
#
#
#
#     // TODO: make a more flexible system.
#     // TODO: Allow "outer", "middle" and "center"
#     var allowed_locations = [['upper', 'right'], ['lower', 'right'], ['lower', 'left'], ['upper', 'left']];
#
#     var draw_legends = function(container_legends, width, height) {
#         /**
#          * This function draws the current legends into the specified container.
#          */
#
#         var legend = container_legends.selectAll('g.matta-legend')
#             .data(active_legends, function(d) { return d['variable']; });
#
#         legend.enter()
#             .append('g')
#             .attr('class', function(d) { return 'matta-legend'; });
#
#         legend.exit()
#             .remove();
#
#         legend.each(function(d, i) {
#             console.log('each legend', d, this);
#             var self = d3.select(this);
#             self.call(d);
#             var bbox = self.node().getBBox();
#             console.log('bbox', bbox);
#
#             // hack to avoid problems with too many legends.
#             var location = allowed_locations[i % allowed_locations.length];
#             console.log('location', location);
#
#             var pos_y = location[0] === 'upper' ? 15 : height - 15 - bbox.height;
#             var pos_x = location[1] === 'left' ? 15 : width - 15 - bbox.width;
#             console.log(pos_x, pos_y);
#             self.attr('transform', 'translate(' + [pos_x, pos_y] + ')');
#         });
#     };
#
#
#
#
#
#         var _padding = {"top": 0, "right": 0, "left": 0, "bottom": 0};
#         func_matta_parsets.padding = function(__) {
#             if (arguments.length) {
#                 _padding = __;
#                 console.log('set padding', _padding);
#                 return func_matta_parsets;
#             }
#             return _padding;
#         };
#
#         var _width = 960;
#         func_matta_parsets.width = function(__) {
#             if (arguments.length) {
#                 _width = __;
#                 console.log('set width', _width);
#                 return func_matta_parsets;
#             }
#             return _width;
#         };
#
#         var _columns = ["Survived", "Sex", "Age", "Class"];
#         func_matta_parsets.columns = function(__) {
#             if (arguments.length) {
#                 _columns = __;
#                 console.log('set columns', _columns);

# %% [markdown]
# ### Graph
#
# Graphs from [`networkx.DiGraph`](http://networkx.github.io/documentation/networkx-1.9.1/reference/classes.digraph.html) are visualized using the [Force Layout in d3.js](https://github.com/mbostock/d3/wiki/Force-Layout).

# %%
graph = nx.davis_southern_women_graph()

# %%
for node in graph.nodes_iter(data=True):
    graph.node[node[0]]['color'] = 'purple' if node[1]['bipartite'] else 'green'
    graph.node[node[0]]['size'] = graph.degree(node[0])

# %%
matta.force(graph=graph, link_distance=100, height=600,
            node_ratio='size',
            node_color={'value': 'bipartite', 'scale': 'ordinal', 'palette': 'Set2'})
# Out:
# <div id="matta-vis-aa816295-c624-403c-8553-67ca8fc5c8aa"></div>
#
# <script type="text/javascript">
# $(function() {
#     var main = function (d3, matta, cola) {
#
# /**
#  *
#  * matta_force was scaffolded using matta - https://github.com/carnby/matta
#  * Variables that start with an underscore (_) are passed as arguments in Python.
#  * Variables that start with _data are data parameters of the visualization, and expected to be given as datum.
#  *
#  * For instance, d3.select('#figure').datum({'graph': a_json_graph, 'dataframe': a_json_dataframe}).call(visualization)
#  * will fill the variables _data_graph and _data_dataframe.
#  *
#  */
#
# var matta_matta_force = function() {
#     "use strict";
#
#     var __fill_data__ = function(__data__) {
#
#             if (__data__.hasOwnProperty('graph')) {
#                 func_matta_force.graph(__data__.graph);
#             } else {
#                 func_matta_force.graph(null);
#             }
#
#     };
#
#
#
#     var func_matta_force = function (selection) {
#         console.log('selection', selection);
#
#         var _vis_width = _width - _padding.left - _padding.right;
#         var _vis_height = _height - _padding.top - _padding.bottom;
#
#         selection.each(function(__data__) {
#             __fill_data__(__data__);
#
#             var container = null;
#             var figure_dom_element = this;
#             var container_legends = null;
#
#             if (d3.select(this).select('svg.matta_force-container').empty()) {
#
#                     var svg = d3.select(this).append('svg')
#                         .attr('width', _width)
#                         .attr('height', _height)
#                         .attr('class', 'matta_force-container');
#
#
#
#                     container = svg.append('g')
#                         .classed('matta_force-container', true)
#                         .attr('transform', 'translate(' + _padding.left + ',' + _padding.top + ')');
#
#                     container_legends = svg.append('g')
#                         .classed('matta_force-legends', true)
#                         .attr('transform', 'translate(' + _padding.left + ',' + _padding.top + ')');
#
#
#             } else {
#                 container = d3.select(this).select('svg.matta_force-container');
#             }
#
#             console.log('container', container.node());
#
#             var fn_collide = function(node) {
#     var nx1, nx2, ny1, ny2, r;
#     r = _node_ratio(node) + _node_padding;
#     nx1 = node.x - r;
#     nx2 = node.x + r;
#     ny1 = node.y - r;
#     ny2 = node.y + r;
#     return function(quad, x1, y1, x2, y2) {
#         var l, r2, x, y;
#         if (quad.point && quad.point !== node) {
#             x = node.x - quad.point.x;
#             y = node.y - quad.point.y;
#             l = Math.sqrt(x * x + y * y);
#             r2 = r + _node_ratio(quad.point);
#
#             if (l < r2) {
#                 l = (l - r2) / l * 0.5;
#                 node.x -= x *= l;
#                 node.y -= y *= l;
#                 quad.point.x += x;
#                 quad.point.y += y;
#             }
#         }
#         return x1 > nx2 || x2 < nx1 || y1 > ny2 || y2 < ny1;
#     };
# };
#
#
#
#
# matta.prepare_graph(_data_graph);
# _node_ratio_update_scale_func(_data_graph.nodes);
# _node_color_update_scale_func(_data_graph.nodes);
# _link_color_update_scale_func(_data_graph.links);
#
#
#
# // we need this to avoid overlaps
# _data_graph.nodes.forEach(function(d) {
#     d.width = _node_ratio(d) * 2 + _node_padding;
#     d.height = _node_ratio(d) * 2 + _node_padding;
# });
#
# console.log(cola);
# var force = cola.d3adaptor()
#     .linkDistance(_link_distance)
#     .size([_vis_width, _vis_height])
#     .avoidOverlaps(_avoid_collisions);
#
#
# var node_g, link_g;
#
# if (!container.select('g.links').empty()) {
#     link_g = container.select('g.links');
# } else {
#     link_g = container.append('g').classed('links', true);
# }
#
# if (!container.select('g.nodes').empty()) {
#     node_g = container.select('g.nodes');
# } else {
#     node_g = container.append('g').classed('nodes', true);
# }
#
# var node = node_g.selectAll("g.node")
#     .data(_data_graph.nodes, function(d, i) { return matta.get(d, _node_id); });
#
# node.enter()
#     .append('g')
#     .attr('class', 'node')
#     .each(function(d) {
#         var ratio = _node_ratio(d);
#         d3.select(this).append('circle')
#             .attr('r', ratio)
#             .attr('cx', ratio)
#             .attr('cy', ratio)
#             .attr('stroke', 'grey')
#             .attr('stroke-width', 2)
#             .attr('fill', _node_color);
#
#         if (_node_labels == true) {
#             d3.select(this).append('text')
#                 .attr('class', 'node-label')
#                 .attr('x', ratio)
#                 .attr('y', ratio)
#                 .attr('dy', '0.35em')
#                 .attr('text-anchor', 'middle')
#                 .attr('font-size', _font_size)
#                 .attr('fill', 'black')
#                 .text(matta.get(d, _node_id));
#         }
#     });
#
# node.exit()
#     .remove();
#
# var link = link_g.selectAll('line.link')
#     .data(_data_graph.links, function(d) {
#         return matta.get(d.source, _node_id) + '-' + matta.get(d.target, _node_id);
#     });
#
# link.enter()
#     .append('line')
#     .classed('link', true)
#     .attr({
#         'stroke': _link_color,
#         'stroke-width': _link_width
#     });
#
# link.exit()
#     .remove();
#
# force.nodes(_data_graph.nodes)
#     .links(_data_graph.links)
#     .on('tick', function(e) {
#
#
#         link.attr({
#             'x1': function(d) {
#                 return d.source.x;
#             },
#             'y1': function(d) {
#                 return d.source.y;
#             },
#             'x2': function(d) {
#                 return d.target.x;
#             },
#             'y2': function(d) {
#                 return d.target.y;
#             }
#         });
#
#         node.attr('transform', function(d) {
#             return 'translate(' + (d.x - _node_ratio(d)) + ', ' + (d.y - _node_ratio(d)) + ')';
#         });
#     });
#
#
# force.start();
#
#         });
#     };
#
#
#         var _data_graph = null;
#         func_matta_force.graph = function(__) {
#             if (arguments.length) {
#                 _data_graph = __;
#                 console.log('DATA graph', _data_graph);
#                 return func_matta_force;
#             }
#             return _data_graph;
#         };
#
#
#     var active_legends = [];
#
#
#
#     var _node_ratio = null;
#     var _node_ratio_scale = null;
#     var _node_ratio_scale_locked = false;
#     var _node_ratio_update_scale_func = d3.functor(null);
#     var _node_ratio_show_legend = false;
#     var _node_ratio_legend = null;
#     var _node_ratio_legend_container = null;
#
#     func_matta_force.node_ratio_scale_locked = function(__) {
#         /**
#          * If node_ratio's scale is locked, then matta_force will not automatically update it
#          * before rendering. Useful to set the scale parameters from outside, or to maintain
#          * coherent scaling between succesive renderings.
#          */
#         if (arguments.length) {
#             _node_ratio_scale_locked = __;
#             console.log('set node_ratio_scale_locked', _node_ratio_scale_locked);
#             return func_matta_force;
#         }
#         return _node_ratio_scale_locked;
#     };
#
#     func_matta_force.node_ratio_scale = function() {
#         /**
#          * Returns the scale for node_ratio.
#          */
#         return _node_ratio_scale;
#     };
#
#     // {'max': '16', 'scale': '"linear"', u'legend': 'false', 'value': '"size"', 'min': '8'}
#     // TODO: create get/setters for these variables
#     var _node_ratio_scale_type = "linear";
#     var _node_ratio_min = 8;
#     var _node_ratio_max = 16;
#     var _node_ratio_value = "size";
#
#     if (typeof(_node_ratio_value) !== 'string') {
#         console.log('node_ratio using a functor', _node_ratio_value);
#         _node_ratio = d3.functor(_node_ratio_value !== null ? _node_ratio_value : _node_ratio_max);
#     } else {
#         _node_ratio_scale = matta.scale(_node_ratio_scale_type);
#         _node_ratio_scale.r
